# %%
import sys

# %%
sys.argv = ['/usr/bin/python','/proj/NIRAL/users/siyangj/NewModels/model_0227_unet/patch_real_noaug.ini']

# %%
import main
# Out:
# Using /proj/NIRAL/users/siyangj/NewModels/model_0227_unet/patch_real_noaug.ini as config file.
# >>> **Network**: UNet Late Fusion

# %%
main.main()
# Out:
# >>> STAGE 1 TRAINING <<<
# >>> MODEL CREATED
# >>> OPTIMIZER CREATED
# >>> TRAINING START
# **Training**: restore last checkpoint from:/proj/NIRAL/users/siyangj/NewModels/model_0227_unet/models/1/patch_pretrain1/snapshot_1000
# INFO:tensorflow:Restoring parameters from /proj/NIRAL/users/siyangj/NewModels/model_0227_unet/models/1/patch_pretrain1/snapshot_1000
# >>>EPOCH 1
# >>> Finished **Preloading Data**
# [ Fri Mar  1 03:25:16 2019], Epoch: [   1], Training Main Loss: [0.334], Lr[0.00044000]
# >>> Finished **Preloading Data**
# [ Fri Mar  1 03:25:17 2019], Epoch: [   1], Validation Main Loss: [0.215]
# >> begin predict nifit image: /proj/NIRAL/users/siyangj/myData/min_normal/T1/1.nrrd
# >> load nifti image finish..shape=(96, 112, 96)
# crop_index (0, 96, 0, 112, 0, 96)
# >> begin predict likelihood of each patch ..
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(1331, 1, 64, 64, 64, 4)
# predit patches of 1 image, cost [128] seconds
# ...
