# %%
import sys

# %%
sys.argv = ['/usr/bin/python','/proj/NIRAL/users/siyangj/NewModels/model_0228_unet_early/patch_real_aug.ini']

# %%
import main
# Out:
# Using /proj/NIRAL/users/siyangj/NewModels/model_0228_unet_early/patch_real_aug.ini as config file.
# >>> **Network**: UNet Early Fusion

# %%
main.main()
# Out:
# >>> STAGE 1 TRAINING <<<
# >>> MODEL CREATED
# >>> OPTIMIZER CREATED
# >>> TRAINING START
# **Training**: restore last checkpoint from:/proj/NIRAL/users/siyangj/NewModels/model_0228_unet_early/models/1/patch_pretrain1/snapshot_best
# INFO:tensorflow:Restoring parameters from /proj/NIRAL/users/siyangj/NewModels/model_0228_unet_early/models/1/patch_pretrain1/snapshot_best
# >>>EPOCH 1
# >>> Finished **Preloading Data**
# >>> Finished **Data Augmentation the 0 th time**
# [ Fri Mar  1 03:33:50 2019], Epoch: [   1], Training Main Loss: [0.373], Lr[0.00044000]
# >>> Finished **Preloading Data**
# [ Fri Mar  1 03:33:51 2019], Epoch: [   1], Validation Main Loss: [0.223]
# >> begin predict nifit image: /proj/NIRAL/users/siyangj/myData/min_normal/T1/1.nrrd
# >> load nifti image finish..shape=(96, 112, 96)
# crop_index (0, 96, 0, 112, 0, 96)
# >> begin predict likelihood of each patch ..
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(1331, 1, 64, 64, 64, 4)
# ...
