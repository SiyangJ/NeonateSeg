# %%
import numpy as np
import tensorflow as tf
import sys
import os

sys.argv = ['/usr/bin/python','/proj/NIRAL/users/siyangj/NewModels/model_0227_unet/patch_real_calculate_weights.ini']

'''
import config
from config import FLAGS

from model import create_optimizers

from train import train_model
import random
from generator import get_training_and_testing_generators
from copy import deepcopy
'''

from main import main
# Out:
# Using /proj/NIRAL/users/siyangj/NewModels/model_0227_unet/patch_real_calculate_weights.ini as config file.
# >>> **Network**: UNet Late Fusion

# %%
main()
# Out:
# >>> STAGE 1 TRAINING <<<
# Tensor("Shape_2:0", shape=(1,), dtype=int32)
# Tensor("Shape_3:0", shape=(1,), dtype=int32)
# Tensor("Shape_4:0", shape=(1,), dtype=int32)
# >>> MODEL CREATED
# >>> OPTIMIZER CREATED
# >>> TRAINING START
# **Training**: restore last checkpoint from:/proj/NIRAL/users/siyangj/NewModels/model_0227_unet/models/1/patch_pretrain1/snapshot_best
# INFO:tensorflow:Restoring parameters from /proj/NIRAL/users/siyangj/NewModels/model_0227_unet/models/1/patch_pretrain1/snapshot_best
# >>>EPOCH 1
# >>> Begin evaluating with ground truth: /proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/1.nrrd
# >> begin predict nifit image: /proj/NIRAL/users/siyangj/myData/min_normal/T1/1.nrrd
# >> load nifti image finish..shape=(96, 112, 96)
# crop_index (0, 96, 0, 112, 0, 96)
# >> begin predict likelihood of each patch; total number: 1000
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(1000, 1, 64, 64, 64, 4)
# >> begin predict likelihood of each patch; total number: 331
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(331, 1, 64, 64, 64, 4)
# **>> img_data_t2  (96, 112, 96)
# final_segmentation  (96, 112, 96)
# >>> Epoch 1 Test: [0.811, 0.845, 0.828]
# >>> Generating data from [['/proj/NIRAL/users/siyangj/myData/min_normal/T1/2.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/T2/2.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/2.nrrd'], ['/proj/NIRAL/users/siyangj/myData/min_normal/T1/3.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/T2/3.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/3.nrrd'], ['/proj/NIRAL/users/siyangj/myData/min_normal/T1/5.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/T2/5.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/5.nrrd'], ['/proj/NIRAL/users/siyangj/myData/min_normal/T1/7.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/T2/7.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/7.nrrd'], ['/proj/NIRAL/users/siyangj/myData/min_normal/T1/4.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/T2/4.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/4.nrrd'], ['/proj/NIRAL/users/siyangj/myData/min_normal/T1/6.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/T2/6.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/6.nrrd']]
# >>> Finished **Preloading Data**
# [ Thu Mar  7 07:33:15 2019], Epoch: [   1], Training Main Loss: [0.266], Lr[0.00044000]
# >>> Generating data from [['/proj/NIRAL/users/siyangj/myData/min_normal/T1/8.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/T2/8.nrrd', '/proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/8.nrrd']]
# >>> Finished **Preloading Data**
# [ Thu Mar  7 07:33:16 2019], Epoch: [   1], Validation Main Loss: [0.180]
# >>>EPOCH 2
# >>> Begin evaluating with ground truth: /proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/1.nrrd
# >> begin predict nifit image: /proj/NIRAL/users/siyangj/myData/min_normal/T1/1.nrrd
# >> load nifti image finish..shape=(96, 112, 96)
# crop_index (0, 96, 0, 112, 0, 96)
# >> begin predict likelihood of each patch; total number: 1000
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(1000, 1, 64, 64, 64, 4)
# >> begin predict likelihood of each patch; total number: 331
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(331, 1, 64, 64, 64, 4)
# **>> img_data_t2  (96, 112, 96)
# final_segmentation  (96, 112, 96)
# >>> Epoch 2 Test: [0.809, 0.847, 0.829]
# [ Thu Mar  7 07:35:43 2019], Epoch: [   2], Training Main Loss: [0.333], Lr[0.00044000]
# [ Thu Mar  7 07:35:44 2019], Epoch: [   2], Validation Main Loss: [0.218]
# >>>EPOCH 3
# >>>EPOCH 4
# >>>EPOCH 5
# >>>EPOCH 6
# >>>EPOCH 7
# >>>EPOCH 8
# >>>EPOCH 9
# >>>EPOCH 10
# >>>EPOCH 11
# >>>EPOCH 12
# >>>EPOCH 13
# >>>EPOCH 14
# >>>EPOCH 15
# >>>EPOCH 16
# >>>EPOCH 17
# >>>EPOCH 18
# >>>EPOCH 19
# >>>EPOCH 20
# [ Thu Mar  7 07:40:03 2019], Epoch: [  20], Training Main Loss: [0.263], Lr[0.00044000]
# [ Thu Mar  7 07:40:04 2019], Epoch: [  20], Validation Main Loss: [0.198]
# >>>EPOCH 21
# >>>EPOCH 22
# >>>EPOCH 23
# >>>EPOCH 24
# >>>EPOCH 25
# >>>EPOCH 26
# >>>EPOCH 27
# >>>EPOCH 28
# >>>EPOCH 29
# >>>EPOCH 30
# >>>EPOCH 31
# >>>EPOCH 32
# >>>EPOCH 33
# >>>EPOCH 34
# >>>EPOCH 35
# >>>EPOCH 36
# >>>EPOCH 37
# >>>EPOCH 38
# >>>EPOCH 39
# >>>EPOCH 40
# [ Thu Mar  7 07:44:52 2019], Epoch: [  40], Training Main Loss: [0.235], Lr[0.00044000]
# [ Thu Mar  7 07:44:53 2019], Epoch: [  40], Validation Main Loss: [0.188]
# >>>EPOCH 41
# >>>EPOCH 42
# >>>EPOCH 43
# >>>EPOCH 44
# >>>EPOCH 45
# >>>EPOCH 46
# >>>EPOCH 47
# >>>EPOCH 48
# >>>EPOCH 49
# >>>EPOCH 50
# >>>EPOCH 51
# >>>EPOCH 52
# >>>EPOCH 53
# >>>EPOCH 54
# >>>EPOCH 55
# >>>EPOCH 56
# >>>EPOCH 57
# >>>EPOCH 58
# >>>EPOCH 59
# >>>EPOCH 60
# [ Thu Mar  7 07:49:40 2019], Epoch: [  60], Training Main Loss: [0.220], Lr[0.00044000]
# [ Thu Mar  7 07:49:41 2019], Epoch: [  60], Validation Main Loss: [0.201]
# >>>EPOCH 61
# >>>EPOCH 62
# >>>EPOCH 63
# >>>EPOCH 64
# >>>EPOCH 65
# >>>EPOCH 66
# >>>EPOCH 67
# >>>EPOCH 68
# >>>EPOCH 69
# >>>EPOCH 70
# >>>EPOCH 71
# >>>EPOCH 72
# >>>EPOCH 73
# >>>EPOCH 74
# >>>EPOCH 75
# >>>EPOCH 76
# >>>EPOCH 77
# >>>EPOCH 78
# >>>EPOCH 79
# >>>EPOCH 80
# [ Thu Mar  7 07:54:28 2019], Epoch: [  80], Training Main Loss: [0.185], Lr[0.00044000]
# [ Thu Mar  7 07:54:28 2019], Epoch: [  80], Validation Main Loss: [0.187]
# >>>EPOCH 81
# >>>EPOCH 82
# >>>EPOCH 83
# >>>EPOCH 84
# >>>EPOCH 85
# >>>EPOCH 86
# >>>EPOCH 87
# >>>EPOCH 88
# >>>EPOCH 89
# >>>EPOCH 90
# >>>EPOCH 91
# >>>EPOCH 92
# >>>EPOCH 93
# >>>EPOCH 94
# >>>EPOCH 95
# >>>EPOCH 96
# >>>EPOCH 97
# >>>EPOCH 98
# >>>EPOCH 99
# >>>EPOCH 100
# [ Thu Mar  7 07:59:15 2019], Epoch: [ 100], Training Main Loss: [0.206], Lr[0.00044000]
# [ Thu Mar  7 07:59:16 2019], Epoch: [ 100], Validation Main Loss: [0.144]
# >>>EPOCH 101
# >>>EPOCH 102
# >>>EPOCH 103
# >>>EPOCH 104
# >>>EPOCH 105
# >>>EPOCH 106
# >>>EPOCH 107
# >>>EPOCH 108
# >>>EPOCH 109
# >>>EPOCH 110
# >>>EPOCH 111
# >>>EPOCH 112
# >>>EPOCH 113
# >>>EPOCH 114
# >>>EPOCH 115
# >>>EPOCH 116
# >>>EPOCH 117
# >>>EPOCH 118
# >>>EPOCH 119
# >>>EPOCH 120
# [ Thu Mar  7 08:04:07 2019], Epoch: [ 120], Training Main Loss: [0.168], Lr[0.00044000]
# [ Thu Mar  7 08:04:08 2019], Epoch: [ 120], Validation Main Loss: [0.138]
# >>>EPOCH 121
# >>>EPOCH 122
# >>>EPOCH 123
# >>>EPOCH 124
# >>>EPOCH 125
# >>>EPOCH 126
# >>>EPOCH 127
# >>>EPOCH 128
# >>>EPOCH 129
# >>>EPOCH 130
# >>>EPOCH 131
# >>>EPOCH 132
# >>>EPOCH 133
# >>>EPOCH 134
# >>>EPOCH 135
# >>>EPOCH 136
# >>>EPOCH 137
# >>>EPOCH 138
# >>>EPOCH 139
# >>>EPOCH 140
# [ Thu Mar  7 08:08:59 2019], Epoch: [ 140], Training Main Loss: [0.194], Lr[0.00044000]
# [ Thu Mar  7 08:09:00 2019], Epoch: [ 140], Validation Main Loss: [0.192]
# >>>EPOCH 141
# >>>EPOCH 142
# >>>EPOCH 143
# >>>EPOCH 144
# >>>EPOCH 145
# >>>EPOCH 146
# >>>EPOCH 147
# >>>EPOCH 148
# >>>EPOCH 149
# >>>EPOCH 150
# >>>EPOCH 151
# >>>EPOCH 152
# >>>EPOCH 153
# >>>EPOCH 154
# >>>EPOCH 155
# >>>EPOCH 156
# >>>EPOCH 157
# >>>EPOCH 158
# >>>EPOCH 159
# >>>EPOCH 160
# [ Thu Mar  7 08:13:48 2019], Epoch: [ 160], Training Main Loss: [0.176], Lr[0.00044000]
# [ Thu Mar  7 08:13:49 2019], Epoch: [ 160], Validation Main Loss: [0.201]
# >>>EPOCH 161
# >>>EPOCH 162
# >>>EPOCH 163
# >>>EPOCH 164
# >>>EPOCH 165
# >>>EPOCH 166
# >>>EPOCH 167
# >>>EPOCH 168
# >>>EPOCH 169
# >>>EPOCH 170
# >>>EPOCH 171
# >>>EPOCH 172
# >>>EPOCH 173
# >>>EPOCH 174
# >>>EPOCH 175
# >>>EPOCH 176
# >>>EPOCH 177
# >>>EPOCH 178
# >>>EPOCH 179
# >>>EPOCH 180
# [ Thu Mar  7 08:18:37 2019], Epoch: [ 180], Training Main Loss: [0.178], Lr[0.00044000]
# [ Thu Mar  7 08:18:38 2019], Epoch: [ 180], Validation Main Loss: [0.136]
# >>>EPOCH 181
# >>>EPOCH 182
# >>>EPOCH 183
# >>>EPOCH 184
# >>>EPOCH 185
# >>>EPOCH 186
# >>>EPOCH 187
# >>>EPOCH 188
# >>>EPOCH 189
# >>>EPOCH 190
# >>>EPOCH 191
# >>>EPOCH 192
# >>>EPOCH 193
# >>>EPOCH 194
# >>>EPOCH 195
# >>>EPOCH 196
# >>>EPOCH 197
# >>>EPOCH 198
# >>>EPOCH 199
# >>>EPOCH 200
# >>> Begin evaluating with ground truth: /proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/1.nrrd
# >> begin predict nifit image: /proj/NIRAL/users/siyangj/myData/min_normal/T1/1.nrrd
# >> load nifti image finish..shape=(96, 112, 96)
# crop_index (0, 96, 0, 112, 0, 96)
# >> begin predict likelihood of each patch; total number: 1000
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(1000, 1, 64, 64, 64, 4)
# >> begin predict likelihood of each patch; total number: 331
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(331, 1, 64, 64, 64, 4)
# **>> img_data_t2  (96, 112, 96)
# final_segmentation  (96, 112, 96)
# >>> Epoch 200 Test: [0.833, 0.850, 0.833]
# [ Thu Mar  7 08:25:36 2019], Epoch: [ 200], Training Main Loss: [0.190], Lr[0.00044000]
# [ Thu Mar  7 08:25:37 2019], Epoch: [ 200], Validation Main Loss: [0.144]
# >>>EPOCH 201
# >>>EPOCH 202
# >>>EPOCH 203
# >>>EPOCH 204
# >>>EPOCH 205
# >>>EPOCH 206
# >>>EPOCH 207
# >>>EPOCH 208
# >>>EPOCH 209
# >>>EPOCH 210
# >>>EPOCH 211
# >>>EPOCH 212
# >>>EPOCH 213
# >>>EPOCH 214
# >>>EPOCH 215
# >>>EPOCH 216
# >>>EPOCH 217
# >>>EPOCH 218
# >>>EPOCH 219
# >>>EPOCH 220
# [ Thu Mar  7 08:30:25 2019], Epoch: [ 220], Training Main Loss: [0.211], Lr[0.00044000]
# [ Thu Mar  7 08:30:25 2019], Epoch: [ 220], Validation Main Loss: [0.152]
# >>>EPOCH 221
# >>>EPOCH 222
# >>>EPOCH 223
# >>>EPOCH 224
# >>>EPOCH 225
# >>>EPOCH 226
# >>>EPOCH 227
# >>>EPOCH 228
# >>>EPOCH 229
# >>>EPOCH 230
# >>>EPOCH 231
# >>>EPOCH 232
# >>>EPOCH 233
# >>>EPOCH 234
# >>>EPOCH 235
# >>>EPOCH 236
# >>>EPOCH 237
# >>>EPOCH 238
# >>>EPOCH 239
# >>>EPOCH 240
# [ Thu Mar  7 08:35:13 2019], Epoch: [ 240], Training Main Loss: [0.186], Lr[0.00044000]
# [ Thu Mar  7 08:35:14 2019], Epoch: [ 240], Validation Main Loss: [0.138]
# >>>EPOCH 241
# >>>EPOCH 242
# >>>EPOCH 243
# >>>EPOCH 244
# >>>EPOCH 245
# >>>EPOCH 246
# >>>EPOCH 247
# >>>EPOCH 248
# >>>EPOCH 249
# >>>EPOCH 250
# >>>EPOCH 251
# >>>EPOCH 252
# >>>EPOCH 253
# >>>EPOCH 254
# >>>EPOCH 255
# >>>EPOCH 256
# >>>EPOCH 257
# >>>EPOCH 258
# >>>EPOCH 259
# >>>EPOCH 260
# [ Thu Mar  7 08:40:03 2019], Epoch: [ 260], Training Main Loss: [0.143], Lr[0.00044000]
# [ Thu Mar  7 08:40:03 2019], Epoch: [ 260], Validation Main Loss: [0.134]
# >>>EPOCH 261
# >>>EPOCH 262
# >>>EPOCH 263
# >>>EPOCH 264
# >>>EPOCH 265
# >>>EPOCH 266
# >>>EPOCH 267
# >>>EPOCH 268
# >>>EPOCH 269
# >>>EPOCH 270
# >>>EPOCH 271
# >>>EPOCH 272
# >>>EPOCH 273
# >>>EPOCH 274
# >>>EPOCH 275
# >>>EPOCH 276
# >>>EPOCH 277
# >>>EPOCH 278
# >>>EPOCH 279
# >>>EPOCH 280
# [ Thu Mar  7 08:44:55 2019], Epoch: [ 280], Training Main Loss: [0.183], Lr[0.00044000]
# [ Thu Mar  7 08:44:55 2019], Epoch: [ 280], Validation Main Loss: [0.135]
# >>>EPOCH 281
# >>>EPOCH 282
# >>>EPOCH 283
# >>>EPOCH 284
# >>>EPOCH 285
# >>>EPOCH 286
# >>>EPOCH 287
# >>>EPOCH 288
# >>>EPOCH 289
# >>>EPOCH 290
# >>>EPOCH 291
# >>>EPOCH 292
# >>>EPOCH 293
# >>>EPOCH 294
# >>>EPOCH 295
# >>>EPOCH 296
# >>>EPOCH 297
# >>>EPOCH 298
# >>>EPOCH 299
# >>>EPOCH 300
# [ Thu Mar  7 08:49:43 2019], Epoch: [ 300], Training Main Loss: [0.176], Lr[0.00044000]
# [ Thu Mar  7 08:49:44 2019], Epoch: [ 300], Validation Main Loss: [0.151]
# >>>EPOCH 301
# >>>EPOCH 302
# >>>EPOCH 303
# >>>EPOCH 304
# >>>EPOCH 305
# >>>EPOCH 306
# >>>EPOCH 307
# >>>EPOCH 308
# >>>EPOCH 309
# >>>EPOCH 310
# >>>EPOCH 311
# >>>EPOCH 312
# >>>EPOCH 313
# >>>EPOCH 314
# >>>EPOCH 315
# >>>EPOCH 316
# >>>EPOCH 317
# >>>EPOCH 318
# >>>EPOCH 319
# >>>EPOCH 320
# [ Thu Mar  7 08:54:32 2019], Epoch: [ 320], Training Main Loss: [0.175], Lr[0.00044000]
# [ Thu Mar  7 08:54:32 2019], Epoch: [ 320], Validation Main Loss: [0.147]
# >>>EPOCH 321
# >>>EPOCH 322
# >>>EPOCH 323
# >>>EPOCH 324
# >>>EPOCH 325
# >>>EPOCH 326
# >>>EPOCH 327
# >>>EPOCH 328
# >>>EPOCH 329
# >>>EPOCH 330
# >>>EPOCH 331
# >>>EPOCH 332
# >>>EPOCH 333
# >>>EPOCH 334
# >>>EPOCH 335
# >>>EPOCH 336
# >>>EPOCH 337
# >>>EPOCH 338
# >>>EPOCH 339
# >>>EPOCH 340
# [ Thu Mar  7 08:59:19 2019], Epoch: [ 340], Training Main Loss: [0.125], Lr[0.00044000]
# [ Thu Mar  7 08:59:20 2019], Epoch: [ 340], Validation Main Loss: [0.125]
# >>>EPOCH 341
# >>>EPOCH 342
# >>>EPOCH 343
# >>>EPOCH 344
# >>>EPOCH 345
# >>>EPOCH 346
# >>>EPOCH 347
# >>>EPOCH 348
# >>>EPOCH 349
# >>>EPOCH 350
# >>>EPOCH 351
# >>>EPOCH 352
# >>>EPOCH 353
# >>>EPOCH 354
# >>>EPOCH 355
# >>>EPOCH 356
# >>>EPOCH 357
# >>>EPOCH 358
# >>>EPOCH 359
# >>>EPOCH 360
# [ Thu Mar  7 09:04:11 2019], Epoch: [ 360], Training Main Loss: [0.150], Lr[0.00044000]
# [ Thu Mar  7 09:04:12 2019], Epoch: [ 360], Validation Main Loss: [0.143]
# >>>EPOCH 361
# >>>EPOCH 362
# >>>EPOCH 363
# >>>EPOCH 364
# >>>EPOCH 365
# >>>EPOCH 366
# >>>EPOCH 367
# >>>EPOCH 368
# >>>EPOCH 369
# >>>EPOCH 370
# >>>EPOCH 371
# >>>EPOCH 372
# >>>EPOCH 373
# >>>EPOCH 374
# >>>EPOCH 375
# >>>EPOCH 376
# >>>EPOCH 377
# >>>EPOCH 378
# >>>EPOCH 379
# >>>EPOCH 380
# [ Thu Mar  7 09:09:00 2019], Epoch: [ 380], Training Main Loss: [0.158], Lr[0.00044000]
# [ Thu Mar  7 09:09:01 2019], Epoch: [ 380], Validation Main Loss: [0.132]
# >>>EPOCH 381
# >>>EPOCH 382
# >>>EPOCH 383
# >>>EPOCH 384
# >>>EPOCH 385
# >>>EPOCH 386
# >>>EPOCH 387
# >>>EPOCH 388
# >>>EPOCH 389
# >>>EPOCH 390
# >>>EPOCH 391
# >>>EPOCH 392
# >>>EPOCH 393
# >>>EPOCH 394
# >>>EPOCH 395
# >>>EPOCH 396
# >>>EPOCH 397
# >>>EPOCH 398
# >>>EPOCH 399
# >>>EPOCH 400
# >>> Begin evaluating with ground truth: /proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/1.nrrd
# >> begin predict nifit image: /proj/NIRAL/users/siyangj/myData/min_normal/T1/1.nrrd
# >> load nifti image finish..shape=(96, 112, 96)
# crop_index (0, 96, 0, 112, 0, 96)
# >> begin predict likelihood of each patch; total number: 1000
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(1000, 1, 64, 64, 64, 4)
# >> begin predict likelihood of each patch; total number: 331
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(331, 1, 64, 64, 64, 4)
# **>> img_data_t2  (96, 112, 96)
# final_segmentation  (96, 112, 96)
# >>> Epoch 400 Test: [0.841, 0.859, 0.835]
# [ Thu Mar  7 09:15:56 2019], Epoch: [ 400], Training Main Loss: [0.179], Lr[0.00037400]
# [ Thu Mar  7 09:15:57 2019], Epoch: [ 400], Validation Main Loss: [0.164]
# >>>EPOCH 401
# >>>EPOCH 402
# >>>EPOCH 403
# >>>EPOCH 404
# >>>EPOCH 405
# >>>EPOCH 406
# >>>EPOCH 407
# >>>EPOCH 408
# >>>EPOCH 409
# >>>EPOCH 410
# >>>EPOCH 411
# >>>EPOCH 412
# >>>EPOCH 413
# >>>EPOCH 414
# >>>EPOCH 415
# >>>EPOCH 416
# >>>EPOCH 417
# >>>EPOCH 418
# >>>EPOCH 419
# >>>EPOCH 420
# [ Thu Mar  7 09:20:45 2019], Epoch: [ 420], Training Main Loss: [0.167], Lr[0.00037400]
# [ Thu Mar  7 09:20:46 2019], Epoch: [ 420], Validation Main Loss: [0.140]
# >>>EPOCH 421
# >>>EPOCH 422
# >>>EPOCH 423
# >>>EPOCH 424
# >>>EPOCH 425
# >>>EPOCH 426
# >>>EPOCH 427
# >>>EPOCH 428
# >>>EPOCH 429
# >>>EPOCH 430
# >>>EPOCH 431
# >>>EPOCH 432
# >>>EPOCH 433
# >>>EPOCH 434
# >>>EPOCH 435
# >>>EPOCH 436
# >>>EPOCH 437
# >>>EPOCH 438
# >>>EPOCH 439
# >>>EPOCH 440
# [ Thu Mar  7 09:25:34 2019], Epoch: [ 440], Training Main Loss: [0.204], Lr[0.00037400]
# [ Thu Mar  7 09:25:35 2019], Epoch: [ 440], Validation Main Loss: [0.135]
# >>>EPOCH 441
# >>>EPOCH 442
# >>>EPOCH 443
# >>>EPOCH 444
# >>>EPOCH 445
# >>>EPOCH 446
# >>>EPOCH 447
# >>>EPOCH 448
# >>>EPOCH 449
# >>>EPOCH 450
# >>>EPOCH 451
# >>>EPOCH 452
# >>>EPOCH 453
# >>>EPOCH 454
# >>>EPOCH 455
# >>>EPOCH 456
# >>>EPOCH 457
# >>>EPOCH 458
# >>>EPOCH 459
# >>>EPOCH 460
# [ Thu Mar  7 09:30:23 2019], Epoch: [ 460], Training Main Loss: [0.180], Lr[0.00037400]
# [ Thu Mar  7 09:30:24 2019], Epoch: [ 460], Validation Main Loss: [0.134]
# >>>EPOCH 461
# >>>EPOCH 462
# >>>EPOCH 463
# >>>EPOCH 464
# >>>EPOCH 465
# >>>EPOCH 466
# >>>EPOCH 467
# >>>EPOCH 468
# >>>EPOCH 469
# >>>EPOCH 470
# >>>EPOCH 471
# >>>EPOCH 472
# >>>EPOCH 473
# >>>EPOCH 474
# >>>EPOCH 475
# >>>EPOCH 476
# >>>EPOCH 477
# >>>EPOCH 478
# >>>EPOCH 479
# >>>EPOCH 480
# [ Thu Mar  7 09:35:12 2019], Epoch: [ 480], Training Main Loss: [0.149], Lr[0.00037400]
# [ Thu Mar  7 09:35:12 2019], Epoch: [ 480], Validation Main Loss: [0.145]
# >>>EPOCH 481
# >>>EPOCH 482
# >>>EPOCH 483
# >>>EPOCH 484
# >>>EPOCH 485
# >>>EPOCH 486
# >>>EPOCH 487
# >>>EPOCH 488
# >>>EPOCH 489
# >>>EPOCH 490
# >>>EPOCH 491
# >>>EPOCH 492
# >>>EPOCH 493
# >>>EPOCH 494
# >>>EPOCH 495
# >>>EPOCH 496
# >>>EPOCH 497
# >>>EPOCH 498
# >>>EPOCH 499
# >>>EPOCH 500
# [ Thu Mar  7 09:40:01 2019], Epoch: [ 500], Training Main Loss: [0.164], Lr[0.00037400]
# [ Thu Mar  7 09:40:02 2019], Epoch: [ 500], Validation Main Loss: [0.160]
# >>>EPOCH 501
# >>>EPOCH 502
# >>>EPOCH 503
# >>>EPOCH 504
# >>>EPOCH 505
# >>>EPOCH 506
# >>>EPOCH 507
# >>>EPOCH 508
# >>>EPOCH 509
# >>>EPOCH 510
# >>>EPOCH 511
# >>>EPOCH 512
# >>>EPOCH 513
# >>>EPOCH 514
# >>>EPOCH 515
# >>>EPOCH 516
# >>>EPOCH 517
# >>>EPOCH 518
# >>>EPOCH 519
# >>>EPOCH 520
# [ Thu Mar  7 09:44:50 2019], Epoch: [ 520], Training Main Loss: [0.146], Lr[0.00037400]
# [ Thu Mar  7 09:44:51 2019], Epoch: [ 520], Validation Main Loss: [0.156]
# >>>EPOCH 521
# >>>EPOCH 522
# >>>EPOCH 523
# >>>EPOCH 524
# >>>EPOCH 525
# >>>EPOCH 526
# >>>EPOCH 527
# >>>EPOCH 528
# >>>EPOCH 529
# >>>EPOCH 530
# >>>EPOCH 531
# >>>EPOCH 532
# >>>EPOCH 533
# >>>EPOCH 534
# >>>EPOCH 535
# >>>EPOCH 536
# >>>EPOCH 537
# >>>EPOCH 538
# >>>EPOCH 539
# >>>EPOCH 540
# [ Thu Mar  7 09:49:39 2019], Epoch: [ 540], Training Main Loss: [0.116], Lr[0.00037400]
# [ Thu Mar  7 09:49:40 2019], Epoch: [ 540], Validation Main Loss: [0.144]
# >>>EPOCH 541
# >>>EPOCH 542
# >>>EPOCH 543
# >>>EPOCH 544
# >>>EPOCH 545
# >>>EPOCH 546
# >>>EPOCH 547
# >>>EPOCH 548
# >>>EPOCH 549
# >>>EPOCH 550
# >>>EPOCH 551
# >>>EPOCH 552
# >>>EPOCH 553
# >>>EPOCH 554
# >>>EPOCH 555
# >>>EPOCH 556
# >>>EPOCH 557
# >>>EPOCH 558
# >>>EPOCH 559
# >>>EPOCH 560
# [ Thu Mar  7 09:54:27 2019], Epoch: [ 560], Training Main Loss: [0.177], Lr[0.00037400]
# [ Thu Mar  7 09:54:28 2019], Epoch: [ 560], Validation Main Loss: [0.150]
# >>>EPOCH 561
# >>>EPOCH 562
# >>>EPOCH 563
# >>>EPOCH 564
# >>>EPOCH 565
# >>>EPOCH 566
# >>>EPOCH 567
# >>>EPOCH 568
# >>>EPOCH 569
# >>>EPOCH 570
# >>>EPOCH 571
# >>>EPOCH 572
# >>>EPOCH 573
# >>>EPOCH 574
# >>>EPOCH 575
# >>>EPOCH 576
# >>>EPOCH 577
# >>>EPOCH 578
# >>>EPOCH 579
# >>>EPOCH 580
# [ Thu Mar  7 09:59:17 2019], Epoch: [ 580], Training Main Loss: [0.205], Lr[0.00037400]
# [ Thu Mar  7 09:59:17 2019], Epoch: [ 580], Validation Main Loss: [0.139]
# >>>EPOCH 581
# >>>EPOCH 582
# >>>EPOCH 583
# >>>EPOCH 584
# >>>EPOCH 585
# >>>EPOCH 586
# >>>EPOCH 587
# >>>EPOCH 588
# >>>EPOCH 589
# >>>EPOCH 590
# >>>EPOCH 591
# >>>EPOCH 592
# >>>EPOCH 593
# >>>EPOCH 594
# >>>EPOCH 595
# >>>EPOCH 596
# >>>EPOCH 597
# >>>EPOCH 598
# >>>EPOCH 599
# >>>EPOCH 600
# >>> Begin evaluating with ground truth: /proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/1.nrrd
# >> begin predict nifit image: /proj/NIRAL/users/siyangj/myData/min_normal/T1/1.nrrd
# >> load nifti image finish..shape=(96, 112, 96)
# crop_index (0, 96, 0, 112, 0, 96)
# >> begin predict likelihood of each patch; total number: 1000
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(1000, 1, 64, 64, 64, 4)
# >> begin predict likelihood of each patch; total number: 331
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(331, 1, 64, 64, 64, 4)
# **>> img_data_t2  (96, 112, 96)
# final_segmentation  (96, 112, 96)
# >>> Epoch 600 Test: [0.832, 0.845, 0.830]
# [ Thu Mar  7 10:06:14 2019], Epoch: [ 600], Training Main Loss: [0.135], Lr[0.00037400]
# [ Thu Mar  7 10:06:15 2019], Epoch: [ 600], Validation Main Loss: [0.136]
# >>>EPOCH 601
# >>>EPOCH 602
# >>>EPOCH 603
# >>>EPOCH 604
# >>>EPOCH 605
# >>>EPOCH 606
# >>>EPOCH 607
# >>>EPOCH 608
# >>>EPOCH 609
# >>>EPOCH 610
# >>>EPOCH 611
# >>>EPOCH 612
# >>>EPOCH 613
# >>>EPOCH 614
# >>>EPOCH 615
# >>>EPOCH 616
# >>>EPOCH 617
# >>>EPOCH 618
# >>>EPOCH 619
# >>>EPOCH 620
# [ Thu Mar  7 10:11:03 2019], Epoch: [ 620], Training Main Loss: [0.163], Lr[0.00037400]
# [ Thu Mar  7 10:11:04 2019], Epoch: [ 620], Validation Main Loss: [0.144]
# >>>EPOCH 621
# >>>EPOCH 622
# >>>EPOCH 623
# >>>EPOCH 624
# >>>EPOCH 625
# >>>EPOCH 626
# >>>EPOCH 627
# >>>EPOCH 628
# >>>EPOCH 629
# >>>EPOCH 630
# >>>EPOCH 631
# >>>EPOCH 632
# >>>EPOCH 633
# >>>EPOCH 634
# >>>EPOCH 635
# >>>EPOCH 636
# >>>EPOCH 637
# >>>EPOCH 638
# >>>EPOCH 639
# >>>EPOCH 640
# [ Thu Mar  7 10:15:52 2019], Epoch: [ 640], Training Main Loss: [0.185], Lr[0.00037400]
# [ Thu Mar  7 10:15:53 2019], Epoch: [ 640], Validation Main Loss: [0.132]
# >>>EPOCH 641
# >>>EPOCH 642
# >>>EPOCH 643
# >>>EPOCH 644
# >>>EPOCH 645
# >>>EPOCH 646
# >>>EPOCH 647
# >>>EPOCH 648
# >>>EPOCH 649
# >>>EPOCH 650
# >>>EPOCH 651
# >>>EPOCH 652
# >>>EPOCH 653
# >>>EPOCH 654
# >>>EPOCH 655
# >>>EPOCH 656
# >>>EPOCH 657
# >>>EPOCH 658
# >>>EPOCH 659
# >>>EPOCH 660
# [ Thu Mar  7 10:20:41 2019], Epoch: [ 660], Training Main Loss: [0.152], Lr[0.00037400]
# [ Thu Mar  7 10:20:41 2019], Epoch: [ 660], Validation Main Loss: [0.148]
# >>>EPOCH 661
# >>>EPOCH 662
# >>>EPOCH 663
# >>>EPOCH 664
# >>>EPOCH 665
# >>>EPOCH 666
# >>>EPOCH 667
# >>>EPOCH 668
# >>>EPOCH 669
# >>>EPOCH 670
# >>>EPOCH 671
# >>>EPOCH 672
# >>>EPOCH 673
# >>>EPOCH 674
# >>>EPOCH 675
# >>>EPOCH 676
# >>>EPOCH 677
# >>>EPOCH 678
# >>>EPOCH 679
# >>>EPOCH 680
# [ Thu Mar  7 10:25:30 2019], Epoch: [ 680], Training Main Loss: [0.123], Lr[0.00037400]
# [ Thu Mar  7 10:25:30 2019], Epoch: [ 680], Validation Main Loss: [0.134]
# >>>EPOCH 681
# >>>EPOCH 682
# >>>EPOCH 683
# >>>EPOCH 684
# >>>EPOCH 685
# >>>EPOCH 686
# >>>EPOCH 687
# >>>EPOCH 688
# >>>EPOCH 689
# >>>EPOCH 690
# >>>EPOCH 691
# >>>EPOCH 692
# >>>EPOCH 693
# >>>EPOCH 694
# >>>EPOCH 695
# >>>EPOCH 696
# >>>EPOCH 697
# >>>EPOCH 698
# >>>EPOCH 699
# >>>EPOCH 700
# [ Thu Mar  7 10:30:18 2019], Epoch: [ 700], Training Main Loss: [0.116], Lr[0.00037400]
# [ Thu Mar  7 10:30:19 2019], Epoch: [ 700], Validation Main Loss: [0.150]
# >>>EPOCH 701
# >>>EPOCH 702
# >>>EPOCH 703
# >>>EPOCH 704
# >>>EPOCH 705
# >>>EPOCH 706
# >>>EPOCH 707
# >>>EPOCH 708
# >>>EPOCH 709
# >>>EPOCH 710
# >>>EPOCH 711
# >>>EPOCH 712
# >>>EPOCH 713
# >>>EPOCH 714
# >>>EPOCH 715
# >>>EPOCH 716
# >>>EPOCH 717
# >>>EPOCH 718
# >>>EPOCH 719
# >>>EPOCH 720
# [ Thu Mar  7 10:35:08 2019], Epoch: [ 720], Training Main Loss: [0.145], Lr[0.00037400]
# [ Thu Mar  7 10:35:08 2019], Epoch: [ 720], Validation Main Loss: [0.146]
# >>>EPOCH 721
# >>>EPOCH 722
# >>>EPOCH 723
# >>>EPOCH 724
# >>>EPOCH 725
# >>>EPOCH 726
# >>>EPOCH 727
# >>>EPOCH 728
# >>>EPOCH 729
# >>>EPOCH 730
# >>>EPOCH 731
# >>>EPOCH 732
# >>>EPOCH 733
# >>>EPOCH 734
# >>>EPOCH 735
# >>>EPOCH 736
# >>>EPOCH 737
# >>>EPOCH 738
# >>>EPOCH 739
# >>>EPOCH 740
# [ Thu Mar  7 10:39:57 2019], Epoch: [ 740], Training Main Loss: [0.118], Lr[0.00037400]
# [ Thu Mar  7 10:39:58 2019], Epoch: [ 740], Validation Main Loss: [0.154]
# >> EARLY STOP: after 400 iterations, still not decreasing
# >> Restore model from iteration 340 at /proj/NIRAL/users/siyangj/NewModels/model_0227_unet/models/1/patch_real_calculate_weights/snapshot_best
# INFO:tensorflow:Restoring parameters from /proj/NIRAL/users/siyangj/NewModels/model_0227_unet/models/1/patch_real_calculate_weights/snapshot_best
# >>>EPOCH 341
# >>>EPOCH 342
# >>>EPOCH 343
# >>>EPOCH 344
# >>>EPOCH 345
# >>>EPOCH 346
# >>>EPOCH 347
# >>>EPOCH 348
# >>>EPOCH 349
# >>>EPOCH 350
# >>>EPOCH 351
# >>>EPOCH 352
# >>>EPOCH 353
# >>>EPOCH 354
# >>>EPOCH 355
# >>>EPOCH 356
# >>>EPOCH 357
# >>>EPOCH 358
# >>>EPOCH 359
# >>>EPOCH 360
# [ Thu Mar  7 10:44:48 2019], Epoch: [ 360], Training Main Loss: [0.150], Lr[0.00037400]
# [ Thu Mar  7 10:44:49 2019], Epoch: [ 360], Validation Main Loss: [0.162]
# >>>EPOCH 361
# >>>EPOCH 362
# >>>EPOCH 363
# >>>EPOCH 364
# >>>EPOCH 365
# >>>EPOCH 366
# >>>EPOCH 367
# >>>EPOCH 368
# >>>EPOCH 369
# >>>EPOCH 370
# >>>EPOCH 371
# >>>EPOCH 372
# >>>EPOCH 373
# >>>EPOCH 374
# >>>EPOCH 375
# >>>EPOCH 376
# >>>EPOCH 377
# >>>EPOCH 378
# >>>EPOCH 379
# >>>EPOCH 380
# [ Thu Mar  7 10:49:37 2019], Epoch: [ 380], Training Main Loss: [0.153], Lr[0.00037400]
# [ Thu Mar  7 10:49:38 2019], Epoch: [ 380], Validation Main Loss: [0.132]
# >>>EPOCH 381
# >>>EPOCH 382
# >>>EPOCH 383
# >>>EPOCH 384
# >>>EPOCH 385
# >>>EPOCH 386
# >>>EPOCH 387
# >>>EPOCH 388
# >>>EPOCH 389
# >>>EPOCH 390
# >>>EPOCH 391
# >>>EPOCH 392
# >>>EPOCH 393
# >>>EPOCH 394
# >>>EPOCH 395
# >>>EPOCH 396
# >>>EPOCH 397
# >>>EPOCH 398
# >>>EPOCH 399
# >>>EPOCH 400
# >>> Begin evaluating with ground truth: /proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/1.nrrd
# >> begin predict nifit image: /proj/NIRAL/users/siyangj/myData/min_normal/T1/1.nrrd
# >> load nifti image finish..shape=(96, 112, 96)
# crop_index (0, 96, 0, 112, 0, 96)
# >> begin predict likelihood of each patch; total number: 1000
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(1000, 1, 64, 64, 64, 4)
# >> begin predict likelihood of each patch; total number: 331
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(331, 1, 64, 64, 64, 4)
# **>> img_data_t2  (96, 112, 96)
# final_segmentation  (96, 112, 96)
# >>> Epoch 400 Test: [0.838, 0.854, 0.836]
# [ Thu Mar  7 10:56:33 2019], Epoch: [ 400], Training Main Loss: [0.163], Lr[0.00031790]
# [ Thu Mar  7 10:56:34 2019], Epoch: [ 400], Validation Main Loss: [0.141]
# >>>EPOCH 401
# >>>EPOCH 402
# >>>EPOCH 403
# >>>EPOCH 404
# >>>EPOCH 405
# >>>EPOCH 406
# >>>EPOCH 407
# >>>EPOCH 408
# >>>EPOCH 409
# >>>EPOCH 410
# >>>EPOCH 411
# >>>EPOCH 412
# >>>EPOCH 413
# >>>EPOCH 414
# >>>EPOCH 415
# >>>EPOCH 416
# >>>EPOCH 417
# >>>EPOCH 418
# >>>EPOCH 419
# >>>EPOCH 420
# [ Thu Mar  7 11:01:22 2019], Epoch: [ 420], Training Main Loss: [0.147], Lr[0.00031790]
# [ Thu Mar  7 11:01:23 2019], Epoch: [ 420], Validation Main Loss: [0.138]
# >>>EPOCH 421
# >>>EPOCH 422
# >>>EPOCH 423
# >>>EPOCH 424
# >>>EPOCH 425
# >>>EPOCH 426
# >>>EPOCH 427
# >>>EPOCH 428
# >>>EPOCH 429
# >>>EPOCH 430
# >>>EPOCH 431
# >>>EPOCH 432
# >>>EPOCH 433
# >>>EPOCH 434
# >>>EPOCH 435
# >>>EPOCH 436
# >>>EPOCH 437
# >>>EPOCH 438
# >>>EPOCH 439
# >>>EPOCH 440
# [ Thu Mar  7 11:06:11 2019], Epoch: [ 440], Training Main Loss: [0.161], Lr[0.00031790]
# [ Thu Mar  7 11:06:11 2019], Epoch: [ 440], Validation Main Loss: [0.142]
# >>>EPOCH 441
# >>>EPOCH 442
# >>>EPOCH 443
# >>>EPOCH 444
# >>>EPOCH 445
# >>>EPOCH 446
# >>>EPOCH 447
# >>>EPOCH 448
# >>>EPOCH 449
# >>>EPOCH 450
# >>>EPOCH 451
# >>>EPOCH 452
# >>>EPOCH 453
# >>>EPOCH 454
# >>>EPOCH 455
# >>>EPOCH 456
# >>>EPOCH 457
# >>>EPOCH 458
# >>>EPOCH 459
# >>>EPOCH 460
# [ Thu Mar  7 11:10:59 2019], Epoch: [ 460], Training Main Loss: [0.138], Lr[0.00031790]
# [ Thu Mar  7 11:11:00 2019], Epoch: [ 460], Validation Main Loss: [0.136]
# >>>EPOCH 461
# >>>EPOCH 462
# >>>EPOCH 463
# >>>EPOCH 464
# >>>EPOCH 465
# >>>EPOCH 466
# >>>EPOCH 467
# >>>EPOCH 468
# >>>EPOCH 469
# >>>EPOCH 470
# >>>EPOCH 471
# >>>EPOCH 472
# >>>EPOCH 473
# >>>EPOCH 474
# >>>EPOCH 475
# >>>EPOCH 476
# >>>EPOCH 477
# >>>EPOCH 478
# >>>EPOCH 479
# >>>EPOCH 480
# [ Thu Mar  7 11:15:48 2019], Epoch: [ 480], Training Main Loss: [0.140], Lr[0.00031790]
# [ Thu Mar  7 11:15:49 2019], Epoch: [ 480], Validation Main Loss: [0.129]
# >>>EPOCH 481
# >>>EPOCH 482
# >>>EPOCH 483
# >>>EPOCH 484
# >>>EPOCH 485
# >>>EPOCH 486
# >>>EPOCH 487
# >>>EPOCH 488
# >>>EPOCH 489
# >>>EPOCH 490
# >>>EPOCH 491
# >>>EPOCH 492
# >>>EPOCH 493
# >>>EPOCH 494
# >>>EPOCH 495
# >>>EPOCH 496
# >>>EPOCH 497
# >>>EPOCH 498
# >>>EPOCH 499
# >>>EPOCH 500
# [ Thu Mar  7 11:20:37 2019], Epoch: [ 500], Training Main Loss: [0.130], Lr[0.00031790]
# [ Thu Mar  7 11:20:38 2019], Epoch: [ 500], Validation Main Loss: [0.139]
# >>>EPOCH 501
# >>>EPOCH 502
# >>>EPOCH 503
# >>>EPOCH 504
# >>>EPOCH 505
# >>>EPOCH 506
# >>>EPOCH 507
# >>>EPOCH 508
# >>>EPOCH 509
# >>>EPOCH 510
# >>>EPOCH 511
# >>>EPOCH 512
# >>>EPOCH 513
# >>>EPOCH 514
# >>>EPOCH 515
# >>>EPOCH 516
# >>>EPOCH 517
# >>>EPOCH 518
# >>>EPOCH 519
# >>>EPOCH 520
# [ Thu Mar  7 11:25:26 2019], Epoch: [ 520], Training Main Loss: [0.139], Lr[0.00031790]
# [ Thu Mar  7 11:25:27 2019], Epoch: [ 520], Validation Main Loss: [0.139]
# >>>EPOCH 521
# >>>EPOCH 522
# >>>EPOCH 523
# >>>EPOCH 524
# >>>EPOCH 525
# >>>EPOCH 526
# >>>EPOCH 527
# >>>EPOCH 528
# >>>EPOCH 529
# >>>EPOCH 530
# >>>EPOCH 531
# >>>EPOCH 532
# >>>EPOCH 533
# >>>EPOCH 534
# >>>EPOCH 535
# >>>EPOCH 536
# >>>EPOCH 537
# >>>EPOCH 538
# >>>EPOCH 539
# >>>EPOCH 540
# [ Thu Mar  7 11:30:15 2019], Epoch: [ 540], Training Main Loss: [0.176], Lr[0.00031790]
# [ Thu Mar  7 11:30:15 2019], Epoch: [ 540], Validation Main Loss: [0.177]
# >>>EPOCH 541
# >>>EPOCH 542
# >>>EPOCH 543
# >>>EPOCH 544
# >>>EPOCH 545
# >>>EPOCH 546
# >>>EPOCH 547
# >>>EPOCH 548
# >>>EPOCH 549
# >>>EPOCH 550
# >>>EPOCH 551
# >>>EPOCH 552
# >>>EPOCH 553
# >>>EPOCH 554
# >>>EPOCH 555
# >>>EPOCH 556
# >>>EPOCH 557
# >>>EPOCH 558
# >>>EPOCH 559
# >>>EPOCH 560
# [ Thu Mar  7 11:35:03 2019], Epoch: [ 560], Training Main Loss: [0.146], Lr[0.00031790]
# [ Thu Mar  7 11:35:04 2019], Epoch: [ 560], Validation Main Loss: [0.159]
# >>>EPOCH 561
# >>>EPOCH 562
# >>>EPOCH 563
# >>>EPOCH 564
# >>>EPOCH 565
# >>>EPOCH 566
# >>>EPOCH 567
# >>>EPOCH 568
# >>>EPOCH 569
# >>>EPOCH 570
# >>>EPOCH 571
# >>>EPOCH 572
# >>>EPOCH 573
# >>>EPOCH 574
# >>>EPOCH 575
# >>>EPOCH 576
# >>>EPOCH 577
# >>>EPOCH 578
# >>>EPOCH 579
# >>>EPOCH 580
# [ Thu Mar  7 11:39:53 2019], Epoch: [ 580], Training Main Loss: [0.139], Lr[0.00031790]
# [ Thu Mar  7 11:39:54 2019], Epoch: [ 580], Validation Main Loss: [0.129]
# >>>EPOCH 581
# >>>EPOCH 582
# >>>EPOCH 583
# >>>EPOCH 584
# >>>EPOCH 585
# >>>EPOCH 586
# >>>EPOCH 587
# >>>EPOCH 588
# >>>EPOCH 589
# >>>EPOCH 590
# >>>EPOCH 591
# >>>EPOCH 592
# >>>EPOCH 593
# >>>EPOCH 594
# >>>EPOCH 595
# >>>EPOCH 596
# >>>EPOCH 597
# >>>EPOCH 598
# >>>EPOCH 599
# >>>EPOCH 600
# >>> Begin evaluating with ground truth: /proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/1.nrrd
# >> begin predict nifit image: /proj/NIRAL/users/siyangj/myData/min_normal/T1/1.nrrd
# >> load nifti image finish..shape=(96, 112, 96)
# crop_index (0, 96, 0, 112, 0, 96)
# >> begin predict likelihood of each patch; total number: 1000
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(1000, 1, 64, 64, 64, 4)
# >> begin predict likelihood of each patch; total number: 331
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(331, 1, 64, 64, 64, 4)
# **>> img_data_t2  (96, 112, 96)
# final_segmentation  (96, 112, 96)
# >>> Epoch 600 Test: [0.839, 0.854, 0.830]
# [ Thu Mar  7 11:46:50 2019], Epoch: [ 600], Training Main Loss: [0.140], Lr[0.00031790]
# [ Thu Mar  7 11:46:51 2019], Epoch: [ 600], Validation Main Loss: [0.144]
# >>>EPOCH 601
# >>>EPOCH 602
# >>>EPOCH 603
# >>>EPOCH 604
# >>>EPOCH 605
# >>>EPOCH 606
# >>>EPOCH 607
# >>>EPOCH 608
# >>>EPOCH 609
# >>>EPOCH 610
# >>>EPOCH 611
# >>>EPOCH 612
# >>>EPOCH 613
# >>>EPOCH 614
# >>>EPOCH 615
# >>>EPOCH 616
# >>>EPOCH 617
# >>>EPOCH 618
# >>>EPOCH 619
# >>>EPOCH 620
# [ Thu Mar  7 11:51:39 2019], Epoch: [ 620], Training Main Loss: [0.113], Lr[0.00031790]
# [ Thu Mar  7 11:51:40 2019], Epoch: [ 620], Validation Main Loss: [0.139]
# >>>EPOCH 621
# >>>EPOCH 622
# >>>EPOCH 623
# >>>EPOCH 624
# >>>EPOCH 625
# >>>EPOCH 626
# >>>EPOCH 627
# >>>EPOCH 628
# >>>EPOCH 629
# >>>EPOCH 630
# >>>EPOCH 631
# >>>EPOCH 632
# >>>EPOCH 633
# >>>EPOCH 634
# >>>EPOCH 635
# >>>EPOCH 636
# >>>EPOCH 637
# >>>EPOCH 638
# >>>EPOCH 639
# >>>EPOCH 640
# [ Thu Mar  7 11:56:28 2019], Epoch: [ 640], Training Main Loss: [0.164], Lr[0.00031790]
# [ Thu Mar  7 11:56:28 2019], Epoch: [ 640], Validation Main Loss: [0.128]
# >>>EPOCH 641
# >>>EPOCH 642
# >>>EPOCH 643
# >>>EPOCH 644
# >>>EPOCH 645
# >>>EPOCH 646
# >>>EPOCH 647
# >>>EPOCH 648
# >>>EPOCH 649
# >>>EPOCH 650
# >>>EPOCH 651
# >>>EPOCH 652
# >>>EPOCH 653
# >>>EPOCH 654
# >>>EPOCH 655
# >>>EPOCH 656
# >>>EPOCH 657
# >>>EPOCH 658
# >>>EPOCH 659
# >>>EPOCH 660
# [ Thu Mar  7 12:01:17 2019], Epoch: [ 660], Training Main Loss: [0.123], Lr[0.00031790]
# [ Thu Mar  7 12:01:18 2019], Epoch: [ 660], Validation Main Loss: [0.143]
# >>>EPOCH 661
# >>>EPOCH 662
# >>>EPOCH 663
# >>>EPOCH 664
# >>>EPOCH 665
# >>>EPOCH 666
# >>>EPOCH 667
# >>>EPOCH 668
# >>>EPOCH 669
# >>>EPOCH 670
# >>>EPOCH 671
# >>>EPOCH 672
# >>>EPOCH 673
# >>>EPOCH 674
# >>>EPOCH 675
# >>>EPOCH 676
# >>>EPOCH 677
# >>>EPOCH 678
# >>>EPOCH 679
# >>>EPOCH 680
# [ Thu Mar  7 12:06:06 2019], Epoch: [ 680], Training Main Loss: [0.169], Lr[0.00031790]
# [ Thu Mar  7 12:06:07 2019], Epoch: [ 680], Validation Main Loss: [0.162]
# >>>EPOCH 681
# >>>EPOCH 682
# >>>EPOCH 683
# >>>EPOCH 684
# >>>EPOCH 685
# >>>EPOCH 686
# >>>EPOCH 687
# >>>EPOCH 688
# >>>EPOCH 689
# >>>EPOCH 690
# >>>EPOCH 691
# >>>EPOCH 692
# >>>EPOCH 693
# >>>EPOCH 694
# >>>EPOCH 695
# >>>EPOCH 696
# >>>EPOCH 697
# >>>EPOCH 698
# >>>EPOCH 699
# >>>EPOCH 700
# [ Thu Mar  7 12:10:55 2019], Epoch: [ 700], Training Main Loss: [0.129], Lr[0.00031790]
# [ Thu Mar  7 12:10:56 2019], Epoch: [ 700], Validation Main Loss: [0.162]
# >>>EPOCH 701
# >>>EPOCH 702
# >>>EPOCH 703
# >>>EPOCH 704
# >>>EPOCH 705
# >>>EPOCH 706
# >>>EPOCH 707
# >>>EPOCH 708
# >>>EPOCH 709
# >>>EPOCH 710
# >>>EPOCH 711
# >>>EPOCH 712
# >>>EPOCH 713
# >>>EPOCH 714
# >>>EPOCH 715
# >>>EPOCH 716
# >>>EPOCH 717
# >>>EPOCH 718
# >>>EPOCH 719
# >>>EPOCH 720
# [ Thu Mar  7 12:15:44 2019], Epoch: [ 720], Training Main Loss: [0.127], Lr[0.00031790]
# [ Thu Mar  7 12:15:45 2019], Epoch: [ 720], Validation Main Loss: [0.143]
# >>>EPOCH 721
# >>>EPOCH 722
# >>>EPOCH 723
# >>>EPOCH 724
# >>>EPOCH 725
# >>>EPOCH 726
# >>>EPOCH 727
# >>>EPOCH 728
# >>>EPOCH 729
# >>>EPOCH 730
# >>>EPOCH 731
# >>>EPOCH 732
# >>>EPOCH 733
# >>>EPOCH 734
# >>>EPOCH 735
# >>>EPOCH 736
# >>>EPOCH 345
# >>>EPOCH 346
# >>>EPOCH 347
# >>>EPOCH 348
# >>>EPOCH 349
# >>>EPOCH 350
# >>>EPOCH 351
# >>>EPOCH 352
# >>>EPOCH 353
# >>>EPOCH 354
# >>>EPOCH 355
# >>>EPOCH 356
# >>>EPOCH 357
# >>>EPOCH 358
# >>>EPOCH 359
# >>>EPOCH 360
# [ Thu Mar  7 12:25:23 2019], Epoch: [ 360], Training Main Loss: [0.151], Lr[0.00031790]
# [ Thu Mar  7 12:25:24 2019], Epoch: [ 360], Validation Main Loss: [0.140]
# >>>EPOCH 361
# >>>EPOCH 362
# >>>EPOCH 363
# >>>EPOCH 364
# >>>EPOCH 365
# >>>EPOCH 366
# >>>EPOCH 367
# >>>EPOCH 368
# >>>EPOCH 369
# >>>EPOCH 370
# >>>EPOCH 371
# >>>EPOCH 372
# >>>EPOCH 373
# >>>EPOCH 374
# >>>EPOCH 375
# >>>EPOCH 376
# >>>EPOCH 377
# >>>EPOCH 378
# >>>EPOCH 379
# >>>EPOCH 380
# [ Thu Mar  7 12:30:11 2019], Epoch: [ 380], Training Main Loss: [0.184], Lr[0.00031790]
# [ Thu Mar  7 12:30:12 2019], Epoch: [ 380], Validation Main Loss: [0.180]
# >>>EPOCH 381
# >>>EPOCH 382
# >>>EPOCH 383
# >>>EPOCH 384
# >>>EPOCH 385
# >>>EPOCH 386
# >>>EPOCH 387
# >>>EPOCH 388
# >>>EPOCH 389
# >>>EPOCH 390
# >>>EPOCH 391
# >>>EPOCH 392
# >>>EPOCH 393
# >>>EPOCH 394
# >>>EPOCH 395
# >>>EPOCH 396
# >>>EPOCH 397
# >>>EPOCH 398
# >>>EPOCH 399
# >>>EPOCH 400
# >>> Begin evaluating with ground truth: /proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/1.nrrd
# >> begin predict nifit image: /proj/NIRAL/users/siyangj/myData/min_normal/T1/1.nrrd
# >> load nifti image finish..shape=(96, 112, 96)
# crop_index (0, 96, 0, 112, 0, 96)
# >> begin predict likelihood of each patch; total number: 1000
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(1000, 1, 64, 64, 64, 4)
# >> begin predict likelihood of each patch; total number: 331
# >> begin vote in overlapped patch..
# in vote: predictions.shape=(331, 1, 64, 64, 64, 4)
# **>> img_data_t2  (96, 112, 96)
# final_segmentation  (96, 112, 96)
# >>> Epoch 400 Test: [0.837, 0.851, 0.827]
# [ Thu Mar  7 12:37:06 2019], Epoch: [ 400], Training Main Loss: [0.176], Lr[0.00027021]
# [ Thu Mar  7 12:37:07 2019], Epoch: [ 400], Validation Main Loss: [0.149]
# >>>EPOCH 401
# >>>EPOCH 402
# >>>EPOCH 403
# >>>EPOCH 404
# >>>EPOCH 405
# >>>EPOCH 406
# >>>EPOCH 407
# >>>EPOCH 408
# >>>EPOCH 409
# >>>EPOCH 410
# >>>EPOCH 411
# >>>EPOCH 412
# >>>EPOCH 413
# >>>EPOCH 414
# >>>EPOCH 415
# >>>EPOCH 416
# >>>EPOCH 417
# >>>EPOCH 418
# >>>EPOCH 419
# >>>EPOCH 420
# [ Thu Mar  7 12:41:55 2019], Epoch: [ 420], Training Main Loss: [0.193], Lr[0.00027021]
# [ Thu Mar  7 12:41:56 2019], Epoch: [ 420], Validation Main Loss: [0.134]
# >>>EPOCH 421
# >>>EPOCH 422
# >>>EPOCH 423
# >>>EPOCH 424
# >>>EPOCH 425
# >>>EPOCH 426
# >>>EPOCH 427
# >>>EPOCH 428
# >>>EPOCH 429
# >>>EPOCH 430
# >>>EPOCH 431
# >>>EPOCH 432
# >>>EPOCH 433
# >>>EPOCH 434
# >>>EPOCH 435
# >>>EPOCH 436
# >>>EPOCH 437
# >>>EPOCH 438
# >>>EPOCH 439
# >>>EPOCH 440
# [ Thu Mar  7 12:46:43 2019], Epoch: [ 440], Training Main Loss: [0.149], Lr[0.00027021]
# [ Thu Mar  7 12:46:44 2019], Epoch: [ 440], Validation Main Loss: [0.132]
# >>>EPOCH 441
# >>>EPOCH 442
# >>>EPOCH 443
# >>>EPOCH 444
# >>>EPOCH 445
# >>>EPOCH 446
# >>>EPOCH 447
# >>>EPOCH 448
# >>>EPOCH 449
# >>>EPOCH 450
# >>>EPOCH 451
# >>>EPOCH 452
# >>>EPOCH 453
# >>>EPOCH 454
# >>>EPOCH 455
# >>>EPOCH 456
# >>>EPOCH 457
# >>>EPOCH 458
# >>>EPOCH 459
# >>>EPOCH 460
# [ Thu Mar  7 12:51:31 2019], Epoch: [ 460], Training Main Loss: [0.151], Lr[0.00027021]
# [ Thu Mar  7 12:51:32 2019], Epoch: [ 460], Validation Main Loss: [0.148]
# >>>EPOCH 461
# >>>EPOCH 462
# >>>EPOCH 463
# >>>EPOCH 464
# >>>EPOCH 465
# >>>EPOCH 466
# >>>EPOCH 467
# >>>EPOCH 468
# >>>EPOCH 469
# >>>EPOCH 470
# >>>EPOCH 471
# >>>EPOCH 472
# >>>EPOCH 473
# >>>EPOCH 474
# >>>EPOCH 475
# >>>EPOCH 476
# >>>EPOCH 477
# >>>EPOCH 478
# >>>EPOCH 479
# >>>EPOCH 480
# [ Thu Mar  7 12:56:20 2019], Epoch: [ 480], Training Main Loss: [0.171], Lr[0.00027021]
# [ Thu Mar  7 12:56:21 2019], Epoch: [ 480], Validation Main Loss: [0.154]
# >>>EPOCH 481
# >>>EPOCH 482
# >>>EPOCH 483
# >>>EPOCH 484
# >>>EPOCH 485
# >>>EPOCH 486
# >>>EPOCH 487
# >>>EPOCH 488
# >>>EPOCH 489
# >>>EPOCH 490
