# %%
import tensorflow as tf

import random
import numpy as np
import os
#from generator import get_training_and_testing_generators

import h5py
import matplotlib.pyplot as plt
# %matplotlib inline
import SimpleITK as sitk

# %%
from util.utils import load_sitk,Dice

# %%
inf_path = '/proj/NIRAL/users/siyangj/NewModels/model_0227_unet/models/1/patch_real_error_map1/prediction-5.nrrd'

# %%
inf_arr = load_sitk(inf_path)

# %%
plt.imshow(inf_arr[:,:,60])

# %%
inf_path2 = '/proj/NIRAL/users/siyangj/NewModels/model_0227_unet/models/1/patch_pretrain1/prediction-5.nrrd'
inf_arr2 = load_sitk(inf_path2)
plt.imshow(inf_arr2[:,:,60])

# %%
inf_1_path = '/proj/NIRAL/users/siyangj/NewModels/model_0227_unet/models/1/patch_pretrain1/prediction-1.nrrd'
inf_1_arr = load_sitk(inf_1_path)
seg_1_path = '/proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/1.nrrd'
seg_1_arr = load_sitk(seg_1_path)

# %%
seg_5_path = '/proj/NIRAL/users/siyangj/myData/min_normal/seg_inf_1/5.nrrd'
seg_5_arr = load_sitk(seg_1_path)

# %%
Dice(inf_1_arr,seg_1_arr)
# Out:
# array([0.99416732, 0.81037851, 0.84462799, 0.82775788])

# %%
plt.imshow(seg_5_arr[:,:,60])
